# %%
# !pip install -q unsloth
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.7/192.7 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 112.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.8/127.8 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 93.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.17.0 requires protobuf<6.0.0,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 8192
dtype = None
load_in_4bit = True

fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit",
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",
]

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen2.5-3B",
    max_seq_length = 8192,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.3.19: Fast Qwen2 patching. Transformers: 4.50.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.56G [00:00<?, ?B/s]
# Sliding Window Attention is enabled but not implemented for `eager`; unexpected results may be encountered.
# generation_config.json:   0%|          | 0.00/171 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.71k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 32,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, d
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
    use_rslora = False,
    loftq_config = None,
)
# Out:
# Unsloth 2025.3.19 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %%
from datasets import load_dataset
dataset = load_dataset("Ashkchamp/Openthoughts_math_filtered_30K", split = "train")
# Out:
# README.md:   0%|          | 0.00/800 [00:00<?, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/148M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/134M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/29439 [00:00<?, ? examples/s]

# %%
EOS_TOKEN = tokenizer.eos_token
def create_prompt(example, train=False):
    """
    Creates a structured prompt that includes:
      - The system text.
      - The question text.
      - A directive to generate chain-of-thought reasoning.
      - The chain-of-thought reasoning from the dataset (if available).
      - The final answer, followed by a unique stop token <|final|> and EOS marker.
    """
    system = str(example.get('system', ''))
    question = str(example.get('problem', ''))
    cot = str(example.get('COT_Reason', ''))
    solution = str(example.get('solution', ''))

    if train:
        prompt = (
            f"System: {system}\n"
            f"Question: {question}\n"
            "Let's reason step by step:\n"
        )
    else:
        prompt = (
            f"System: {system}\n"
            f"Question: {question}\n"
            "Let's reason step by step:\n"
            f"{cot}\n"
            "Therefore, the final answer is:\n"
            f"{solution}<|final|>{EOS_TOKEN}"
        )
    return prompt

# %%
create_prompt(dataset[1], train = True)
# Out:
# "System: Your role as an assistant involves thoroughly exploring questions through a systematic long thinking process before providing the final precise and accurate solutions. This requires engaging in a comprehensive cycle of analysis, summarizing, exploration, reassessment, reflection, backtracing, and iteration to develop well-considered thinking process. Please structure your response into two main sections: Thought and Solution. In the Thought section, detail your reasoning process using the specified format: <|begin_of_thought|> {thought with steps separated with '\\n\\n'} <|end_of_thought|> Each step should include detailed considerations such as analisying questions, summarizing relevant findings, brainstorming new ideas, verifying the accuracy of the current steps, refining any errors, and revisiting previous steps. In the Solution section, based on various attempts, explorations, and reflections from the Thought section, systematically present the final solution that you deem correct. The solution should remain a logical, accurate, concise expression style and detail necessary step needed to reach the conclusion, formatted as follows: <|begin_of_solution|> {final formatted, precise, and clear solution} <|end_of_solution|> Now, try to solve the following question through the above guidelines:\nQuestion: Let \\( p = 2^{3009}, q = 3^{2006}, \\) and \\( r = 5^{1003} \\). Which of the following statements is true?\n(A) \\( p < q < r \\)\n(B) \\( p < r < q \\)\n(C) \\( q < p < r \\)\n(D) \\( r < p < q \\)\n(E) \\( q < r < p \\)\nLet's reason step by step:\n"

# %%
def tokenize_function(batch, train=True):
    # Build prompts for each example in the batch
    prompts = []
    batch_size = len(batch["problem"])
    for i in range(batch_size):
        ex = {
            "system": batch["system"][i] if "system" in batch else "",
            "problem": batch["problem"][i],
            "COT_Reason": batch["COT_Reason"][i] if "COT_Reason" in batch else "",
            "solution": batch["solution"][i],
        }
        prompts.append(create_prompt(ex, train=train))

    tokenized = tokenizer(
        prompts,
        truncation=True,
        max_length=8192,
        padding="max_length"
    )

    # Save the original prompt text in the "text" field as required by SFTTrainer
    tokenized["text"] = prompts
    return tokenized

# %%
tokenized_train = dataset.map(tokenize_function, batched=True, remove_columns=dataset.column_names)
# Out:
# Map:   0%|          | 0/29439 [00:00<?, ? examples/s]

# %%
from trl import SFTTrainer
from transformers import TrainingArguments, DataCollatorForLanguageModeling
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=tokenized_train,
    dataset_text_field="text",
    max_seq_length=8192,
    dataset_num_proc=2,
    packing=False,
    data_collator=DataCollatorForLanguageModeling(tokenizer, mlm=False),
    args=TrainingArguments(
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,
        warmup_steps=5,
        # num_train_epochs = 1,
        max_steps=120,
        learning_rate=2e-5,
        fp16=not is_bfloat16_supported(),
        bf16=is_bfloat16_supported(),
        logging_steps=10,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        output_dir="outputs",
        report_to="none",
    ),
)

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 29,439 | Num Epochs = 1 | Total steps = 120
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 59,867,136/3,000,000,000 (2.00% trained)
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 3:08:13, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.436300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.245400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.013900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.758400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.410600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.065300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.737400</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.424300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.315600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.262600</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.234500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.259900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=120, training_loss=1.0970043778419494, metrics={'train_runtime': 11389.1863, 'train_samples_per_second': 0.084, 'train_steps_per_second': 0.011, 'total_flos': 1.3375513854738432e+17, 'train_loss': 1.0970043778419494})

# %%
from IPython.display import Markdown, display

FastLanguageModel.for_inference(model)

# Prepare an example for inference.
# For inference, leave 'COT_Reason' and 'solution' empty so the model generates them.
example = {
    "system": (
        "Your role as an assistant involves thoroughly exploring questions through a systematic long thinking process before providing the final precise and accurate solutions. "
        "This requires engaging in a comprehensive cycle of analysis, summarizing, exploration, reassessment, reflection, backtracing, and iteration to develop well-considered thinking process. "
        "Please structure your response into two main sections: Thought and Solution. In the Thought section, detail your reasoning process using the specified format: "
        "<|begin_of_thought|> {thought with steps separated with '\\n\\n'} <|end_of_thought|> "
        "Each step should include detailed considerations such as analyzing questions, summarizing relevant findings, brainstorming new ideas, verifying the accuracy of the current steps, refining any errors, and revisiting previous steps. "
        "In the Solution section, based on various attempts, explorations, and reflections from the Thought section, systematically present the final solution that you deem correct. "
        "The solution should remain a logical, accurate, concise expression style and detail necessary step needed to reach the conclusion, formatted as follows: "
        "<|begin_of_solution|> {final formatted, precise, and clear solution} <|end_of_solution|> "
        "Now, try to solve the following question through the above guidelines."
    ),
    "problem": (
        "A farmer has three types of animals: chickens, goats, and cows.\n\n"
        "Each chicken has 2 legs\n"
        "Each goat has 4 legs\n"
        "Each cow has 4 legs\n\n"
        "The farmer has twice as many chickens as goats, and 3 fewer cows than goats."
    ),
    "COT_Reason": "",
    "solution": ""
}

# Use train=True so that the prompt ends with "Let's reason step by step:".
prompt = create_prompt(example, train=True)

inputs = tokenizer([prompt], return_tensors="pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens=1024, use_cache=True)

result = tokenizer.batch_decode(outputs)

markdown_output = "\n\n".join(result)

# Display the result as Markdown.
display(Markdown(markdown_output))
# Out:
# System: Your role as an assistant involves thoroughly exploring questions through a systematic long thinking process before providing the final precise and accurate solutions. This requires engaging in a comprehensive cycle of analysis, summarizing, exploration, reassessment, reflection, backtracing, and iteration to develop well-considered thinking process. Please structure your response into two main sections: Thought and Solution. In the Thought section, detail your reasoning process using the specified format: <|begin_of_thought|> {thought with steps separated with '\n\n'} <|end_of_thought|> Each step should include detailed considerations such as analyzing questions, summarizing relevant findings, brainstorming new ideas, verifying the accuracy of the current steps, refining any errors, and revisiting previous steps. In the Solution section, based on various attempts, explorations, and reflections from the Thought section, systematically present the final solution that you deem correct. The solution should remain a logical, accurate, concise expression style and detail necessary step needed to reach the conclusion, formatted as follows: <|begin_of_solution|> {final formatted, precise, and clear solution} <|end_of_solution|> Now, try to solve the following question through the above guidelines.
# Question: A farmer has three types of animals: chickens, goats, and cows.
#
# Each chicken has 2 legs
# Each goat has 4 legs
# Each cow has 4 legs
#
# The farmer has twice as many chickens as goats, and 3 fewer cows than goats.
# Let's reason step by step:
# <|begin_of_thought|>
# - First, let's define the variables for the number of each type of animal. Let \( g \) represent the number of goats, \( c \) represent the number of chickens, and \( k \) represent the number of cows.
# - According to the problem, the farmer has twice as many chickens as goats, so we can write the equation: \( c = 2g \).
# - The problem also states that the farmer has 3 fewer cows than goats, so we can write the equation: \( k = g - 3 \).
# - Now, let's calculate the total number of legs for each type of animal. Each chicken has 2 legs, so the total number of chicken legs is \( 2c \).
# - Each goat has 4 legs, so the total number of goat legs is \( 4g \).
# - Each cow has 4 legs, so the total number of cow legs is \( 4k \).
# - To find the total number of legs, we need to sum the legs of all the animals. The total number of legs is \( 2c + 4g + 4k \).
# - Substituting the expressions for \( c \) and \( k \) in terms of \( g \), we get: \( 2(2g) + 4g + 4(g - 3) \).
# - Simplifying this expression, we get: \( 4g + 4g + 4g - 12 = 12g - 12 \).
# - Therefore, the total number of legs is \( 12g - 12 \).
# - To find the number of goats, we need to determine the value of \( g \). Since the problem does not provide any additional information about the total number of legs, we cannot determine the exact number of goats without more information.
# - However, we can express the total number of legs in terms of \( g \) as \( 12g - 12 \).
# <|end_of_thought|>
#
# <|begin_of_solution|>
# The total number of legs is \( 12g - 12 \), where \( g \) is the number of goats.
# <|end_of_solution|><|endoftext|>

# %%
from IPython.display import Markdown, display

# Enable native 2x faster inference
FastLanguageModel.for_inference(model)

# Prepare an example for inference.
# For inference, leave 'COT_Reason' and 'solution' empty so the model generates them.
example = {
    "system": (
        "Your role as an assistant involves thoroughly exploring questions through a systematic long thinking process before providing the final precise and accurate solutions. "
        "This requires engaging in a comprehensive cycle of analysis, summarizing, exploration, reassessment, reflection, backtracing, and iteration to develop a well-considered thinking process. "
        "Please structure your response into two main sections: Thought and Solution. In the Thought section, detail your reasoning process using the specified format: "
        "<|begin_of_thought|> {thought with steps separated with '\\n\\n'} <|end_of_thought|> "
        "Each step should include detailed considerations such as analyzing questions, summarizing relevant findings, brainstorming new ideas, verifying the accuracy of the current steps, refining any errors, and revisiting previous steps. "
        "In the Solution section, based on various attempts, explorations, and reflections from the Thought section, systematically present the final solution that you deem correct. "
        "The solution should remain a logical, accurate, concise expression style and detail the necessary steps needed to reach the conclusion, formatted as follows: "
        "<|begin_of_solution|> {final formatted, precise, and clear solution} <|end_of_solution|> "
        "Now, try to solve the following question through the above guidelines."
    ),
    "problem": (
        "Emily buys the following three items from an online store:\n\n"
        "A shirt for $12.45\n"
        "A pair of socks for $7.99\n"
        "A sweater for $25.10\n\n"
        "She applies a coupon that gives 10% off the total cost of these items. After the discount, an 8% sales tax is applied to the discounted total. "
        "Finally, there is a $3.00 shipping fee added to the purchase.\n\n"
        "Question: What is Emily’s final total amount (to the nearest cent) after the discount, sales tax, and shipping fee?"
    ),
    "COT_Reason": "",
    "solution": ""
}

# Create the prompt using the new template.
# Use train=True so that the prompt ends with "Let's reason step by step:".
prompt = create_prompt(example, train=True)

# Tokenize the prompt.
inputs = tokenizer([prompt], return_tensors="pt").to("cuda")

# Generate output from the model.
outputs = model.generate(**inputs, max_new_tokens=1024, use_cache=True)

# Decode the generated tokens.
result = tokenizer.batch_decode(outputs)

# Join the output with newlines for better Markdown formatting.
markdown_output = "\n\n".join(result)

# Display the result as Markdown.
display(Markdown(markdown_output))
# Out:
# System: Your role as an assistant involves thoroughly exploring questions through a systematic long thinking process before providing the final precise and accurate solutions. This requires engaging in a comprehensive cycle of analysis, summarizing, exploration, reassessment, reflection, backtracing, and iteration to develop a well-considered thinking process. Please structure your response into two main sections: Thought and Solution. In the Thought section, detail your reasoning process using the specified format: <|begin_of_thought|> {thought with steps separated with '\n\n'} <|end_of_thought|> Each step should include detailed considerations such as analyzing questions, summarizing relevant findings, brainstorming new ideas, verifying the accuracy of the current steps, refining any errors, and revisiting previous steps. In the Solution section, based on various attempts, explorations, and reflections from the Thought section, systematically present the final solution that you deem correct. The solution should remain a logical, accurate, concise expression style and detail the necessary steps needed to reach the conclusion, formatted as follows: <|begin_of_solution|> {final formatted, precise, and clear solution} <|end_of_solution|> Now, try to solve the following question through the above guidelines.
# Question: Emily buys the following three items from an online store:
#
# A shirt for $12.45
# A pair of socks for $7.99
# A sweater for $25.10
#
# She applies a coupon that gives 10% off the total cost of these items. After the discount, an 8% sales tax is applied to the discounted total. Finally, there is a $3.00 shipping fee added to the purchase.
#
# Question: What is Emily’s final total amount (to the nearest cent) after the discount, sales tax, and shipping fee?
# Let's reason step by step:
# <|begin_of_thought|>
# 1. First, let's calculate the total cost of the items before any discounts or taxes:
#    Total cost = $12.45 (shirt) + $7.99 (socks) + $25.10 (sweater)
#    Total cost = $45.54
#
# 2. Next, we apply the 10% discount to the total cost:
#    Discount amount = 10% of $45.54
#    Discount amount = 0.10 * $45.54
#    Discount amount = $4.554
#
# 3. Now, let's subtract the discount amount from the total cost to find the discounted total:
#    Discounted total = $45.54 - $4.554
#    Discounted total = $40.986
#
# 4. Next, we apply the 8% sales tax to the discounted total:
#    Sales tax amount = 8% of $40.986
#    Sales tax amount = 0.08 * $40.986
#    Sales tax amount = $3.27888
#
# 5. Now, let's add the sales tax amount to the discounted total to find the total cost after tax:
#    Total cost after tax = $40.986 + $3.27888
#    Total cost after tax = $44.26488
#
# 6. Finally, we add the $3.00 shipping fee to the total cost after tax to find the final total amount:
#    Final total amount = $44.26488 + $3.00
#    Final total amount = $47.26488
#
# 7. To round the final total amount to the nearest cent, we look at the hundredths place (8) and decide to round up to the nearest cent:
#    Final total amount = $47.26 (rounded to the nearest cent)
# <|end_of_thought|>
#
# <|begin_of_solution|>
# Emily's final total amount after the discount, sales tax, and shipping fee is $47.26 (rounded to the nearest cent).
# <|end_of_solution|><|endoftext|>

# %%
from huggingface_hub import interpreter_login, notebook_login
interpreter_login()
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
# Enter your token (input will not be visible): ··········
# Add token as git credential? (Y/n) n

# %%
loc = '/content/drive/MyDrive/First Semester/Model'
model.save_pretrained(loc)
tokenizer.save_pretrained(loc)
# Out:
# ('/content/drive/MyDrive/First Semester/Model/tokenizer_config.json',
#  '/content/drive/MyDrive/First Semester/Model/special_tokens_map.json',
#  '/content/drive/MyDrive/First Semester/Model/vocab.json',
#  '/content/drive/MyDrive/First Semester/Model/merges.txt',
#  '/content/drive/MyDrive/First Semester/Model/added_tokens.json',
#  '/content/drive/MyDrive/First Semester/Model/tokenizer.json')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
